# %% [markdown]
# <a href="https://colab.research.google.com/github/DennisDo1708/Data-Analytics-Porfollio/blob/main/M3_1_Pandas_101_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)

# %% [markdown]
# ##**Please make a copy of the Google Colab notebook before you start!**

# %% [markdown]
# # M3.1 - Pandas 101 Exam

# %%
#@title Run this to start the exam
# !pip install -qU cspyexamclient

from cspyexamclient import Submission

submission = Submission(exam_id="M31")
submission.register_student()
# Out:
# HTML(value='\n            Please enter the email that you used to register for the course.<br />\n            …
# Text(value='', description='Your email', placeholder='Email..')
# Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), tooltip='Submit'…
# Output()

# %% [markdown]
# **Import data and libraries**
#
# Run the following cell in order to load data

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/anhquan0412/dataset/main/Salaries.csv')
df.drop(columns=['Notes','Status', 'Agency'], inplace=True)
df['JobTitle'] = df['JobTitle'].str.title()

df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  General Manager-Metropolitan Transit Authority
# 1   2       GARY JIMENEZ                 Captain Iii (Police Department)
# 2   3     ALBERT PARDINI                 Captain Iii (Police Department)
# 3   4  CHRISTOPHER CHONG            Wire Rope Cable Maintenance Mechanic
# 4   5    PATRICK GARDNER    Deputy Chief Of Department,(Fire Department)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %% [markdown]
# ---

# %% [markdown]
# ## PART I: MULTIPLE CHOICES (60 pts)

# %%
#@title Question 1 (5 pts)
submission.generate_question(0)
# Out:
# What is the shape of the dataframe?
#
# A. 2 Dimensions
#
# B. (148654,)
#
# C. (10, 148654)
#
# D. (148654, 10)
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 2 (5 pts)
submission.generate_question(1)
# Out:
# Assume that every employee has a different name, how many employees are there in the dataset?
#
# A. 110811
#
# B. 148654
#
# C. 110810
#
# D. 148652
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 3 (5 pts)
submission.generate_question(2)
# Out:
# What is the average Base Pay of the whole dataset?
#
# A. 66325.45
#
# B. 65007.45
#
# C. 5066.05
#
# D. 74768.32
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 4 (5 pts)
submission.generate_question(3)
# Out:
# Which of the observations is FALSE about the San Francisco employees?
#
# A. The size of the city government slightly grew from 2011 to 2014 (in term of number of employees)
#
# B. However, average of total pay increased steadily throughout the years thanks to better payment policy.
#
# C. The average amount of overtime pay also increased.
#
# D. Maximum amount of Base Pay reached about 319.000 USD in 2014.
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 5 (5 pts)
submission.generate_question(4)
# Out:
# What is the name of the highest paid person (including benefits)?
#
# A. WILLIAM J. COAKER JR.
#
# B. NATHANIEL FORD
#
# C. JOE LOPEZ
#
# D. GREGORY P SUHR
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 6 (5 pts)
submission.generate_question(5)
# Out:
# What is his job title?
#
# A. General Manager-Metropolitan Transit Authority
#
# B. Special Nurse
#
# C. Chief of Police
#
# D. Chief Investment Officer
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 7 (5 pts)
submission.generate_question(6)
# Out:
# What is the name of the lowest paid person (including benefits)?
#
# A. WILLIAM J. COAKER JR.
#
# B. NATHANIEL FORD
#
# C. JOE LOPEZ
#
# D. LILLER JACKSON
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 8 (5 pts)
submission.generate_question(7)
# Out:
# How much did the person in Question 7 get paid (TotalPay) in 2014?
#
# A. -618.13
#
# B. 618.13
#
# C. -257.56
#
# D. 257.56
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 9 (5 pts)
submission.generate_question(8)
# Out:
# How many unique employees have the same Job Title with `Liller Jackson` in the dataset?
#
# A. 72
#
# B. 73
#
# C. 74
#
# D. 75
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 10 (5 pts)
submission.generate_question(9)
# Out:
# How many percentage of Special Nurse get paid overtime?
#
# A. About 76%
#
# B. About 56%
#
# C. About 26%
#
# D. About 6%
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 11 (5 pts)
submission.generate_question(10)
# Out:
# Among employees who have TotalPay higher than the average TotalPay, how many unique Job Titles do they hold?
#
# A. 1305
#
# B. 1306
#
# C. 1307
#
# D. 1308
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %%
#@title Question 12 (5 pts)
submission.generate_question(11)
# Out:
# How many Job Titles were represented by only one person in 2013?
#
# A. 202
#
# B. 203
#
# C. 204
#
# D. 205
# RadioButtons(description='Your answer:', options=('A', 'B', 'C', 'D'), value=None)
# ...
# Output()

# %% [markdown]
# ## PART II: EXPRESSIONS (40 pts)
#
# This section asks you to submit a single Pandas expression to answer the question.
#
# > An expression is a combination of values, variables, operators, and function calls that are **evaluated to produce a value**. It does not perform any action but simply returns a result.
#
# Don't mistake them with statements
# > A statement is an instruction that performs an action, such as creating variables, controlling flow, or defining functions. A statement may contain expressions but does not return a value.
#
# Examples:
#
# ```python
# >>> 5 + 3               # Evaluates to 8
# >>> len("hello")        # Evaluates to 5
# >>> df['Salary'] > 50000  # Evaluates to a boolean series
# >>> pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]}) # Evaluates to a dataframe
# ```
#
# Examples of not an expression:
# ```python
# >>> x = y + 2
# >>> df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
# >>> df.drop(columns=['Salary'], inplace=True)
# >>> df.rename(columns={'Name': 'FullName'}, inplace=True)
# ```

# %%
#@title Question 13 (15 pts)
submission.generate_question(12)
# Out:
# Write a single line of code to return **all information** of employees whose TotalPay are higher than the average TotalPay.
#
# *Your output should look like this*
#
# <img src='https://i.imgur.com/5u2IcMS.png' width=1000>
# Textarea(value='', layout=Layout(height='300px', width='600px'), placeholder='Enter your answer here...')
# ...
# Output()

# %%
#@title Question 14 (15 pts)
submission.generate_question(13)
# Out:
# Write a single line of code to return top 5 most common jobs.
#
# *Your output should look like this*
#
# ```
# Transit Operator    9424
# Special Nurse       5791
# Registered Nurse    4955
# Custodian           3214
# Firefighter         3153
# Name: JobTitle, dtype: int64
# ```
# Textarea(value='', layout=Layout(height='300px', width='600px'), placeholder='Enter your answer here...')
# ...
# Output()

# %%
#@title Question 15 (10 pts)
submission.generate_question(14)
# Out:
# Among those 5 most common Job Titles of the whole dataset, how have the avarage Base Pay, Overtime Pay, and Total Pay changed over 4 years of the dataset? Write a **single-line** expression for your answer
#
# Hint: Start by identifying the most common jobs, then filter the dataset before computing the summary.
#
# You may use functions like `isin()`, `value_counts()`.
#
# *Your output should look like this.*
#
# <img src='https://i.imgur.com/YUANVVF.png' width=1000>
# Textarea(value='', layout=Layout(height='300px', width='600px'), placeholder='Enter your answer here...')
# ...
# Output()

# %% [markdown]
# ---

# %% [markdown]
# # Summary

# %%
# Run to see submission summary
submission.display_submission_summary()
# Out:
# HTML(value='\n        <table style="width:100%; border-collapse: collapse;" border="1">\n            <tr>\n   …
# ...
# Output()
